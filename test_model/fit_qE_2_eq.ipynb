# %%
import incense
import sys
sys.path.append("../")
import config.params as config
from utils_analysis import plot_exp, print_system, load_json_data, plot_error_bars
import matplotlib.pyplot as plt
import seaborn as sb
import glob
import os
import numpy as np


ext = ".png"
# Folder and file name for saving images and JSON data
save_folder = "images/qE/"

# %%
loader = incense.ExperimentLoader(mongo_uri=config.mongo_uri, db_name="fit_data_test")

# %%
dict_data = {"4_params": [211, 212, 213, 214],
             "3_sc2":[215, 216, 217, 218], 
             "3_sc": [219, 220, 221],
             #"3_relation": [235, 236, 237],
             "3_kq": [239, 240, 241,242],
             "2_kq_sc2": [243, 244, 245, 246], 
             "2_kq_sc": [247, 248, 249, 250]

            }


# Indices for fluorescence data
v0, v1 = 0, 1

for key in dict_data:
    plot_exp(dict_data[key], v0, v1, save_folder, key, ext, loader)

# %%
dict_data
# Out:
# {'4_params': [211, 212, 213, 214],
#  '3_sc2': [215, 216, 217, 218],
#  '3_sc': [219, 220, 221],
#  '3_kq': [239, 240, 241, 242],
#  '2_kq_sc2': [243, 244, 245, 246],
#  '2_kq_sc': [247, 248, 249, 250]}

# %%
json_files = glob.glob(save_folder + "/*.json")

plot_error_bars(json_files)
# Out:
# [[0.0020589315284939985, 0.0009365544313015172, 0.0012920593562916808, 0.0010082897563317888], [0.0010149733189040652, 0.001769223618534709, 0.002277740021132939, 0.0010472236388519185], [0.0008904832192112461, 0.0008887628110097753, 0.0012262113708767603, 0.0016688262611015765], [0.0010608747368565747, 0.001270284710392112, 0.0008779267731302227], [0.004268473543849913, 0.0010643047156467607, 0.0016452699302631265, 0.0009002500916520342], [0.001035188695222097, 0.0012251009560999661, 0.0008761392482826473, 0.001643414473876296]]
# C:\Users\Alienor\Documents\Projects\DREAM\NPQsimple\test_model\..\utils_analysis.py:97: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0. You can remove the line between points with `linestyle='none'`.
#
#   sb.pointplot(x = np.concatenate(file_names), y =np.concatenate(errors), join=False)
